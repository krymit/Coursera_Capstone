# %% [markdown]
# # Toronto Neighbourhoods Clusters

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

import folium # map rendering library

from bs4 import BeautifulSoup

# %% [markdown]
# ### Parse a wikipedia table with BeautifulSoup to obtain postcodes, borough and neighbourhood names

# %%
website_url = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text
soup = BeautifulSoup(website_url,'lxml')
table = soup.find('table',{'class':'wikitable sortable'})

tdlist = table.findAll('td')

# %%
# first element of tdlist is the postcode, second element is the borough name and third element is the neighbourhood name

postcodes = []
bor = []
neigh = []

count = 1
for idx, l in enumerate(tdlist):    
    if count == 1:
        postcodes.append(l.get_text())
        count += 1
    elif count == 2:
        bor.append(l.get_text())
        count += 1
    elif count == 3:
        neigh.append(l.get_text().strip())
        count = 1

# %% [markdown]
# ### Construct a dataframe with the Toronto neighbourhood information

# %%
toronto = pd.DataFrame()
toronto['Postcode'] = postcodes
toronto['Borough'] = bor
toronto['Neighbourhood'] = neigh

# %%
# remove rows where the borough is 'Not assigned' to a  postcode

toronto = toronto[toronto['Borough'] != 'Not assigned']

# %%
# search for not assigned neighbourhoods and name them after the borough

for idx, row in toronto.iterrows():
    if str(row['Neighbourhood']) == 'Not assigned':
        toronto.at[idx, 'Neighbourhood'] = str(row['Borough'])

# %%
# group neighbourhoods with the same postcode

toronto = toronto.groupby(['Postcode', 'Borough'])['Neighbourhood'].apply(', '.join).reset_index()

# %%
toronto.head()
# Out:
#   Postcode      Borough                           Neighbourhood
# 0      M1B  Scarborough                          Rouge, Malvern
# 1      M1C  Scarborough  Highland Creek, Rouge Hill, Port Union
# 2      M1E  Scarborough       Guildwood, Morningside, West Hill
# 3      M1G  Scarborough                                  Woburn
# 4      M1H  Scarborough                               Cedarbrae

# %%
toronto.shape
# Out:
# (103, 3)

# %% [markdown]
# ### Add latitude and longitude values for each neighbourhood

# %%
import geocoder

# %%
#iterate through the postcodes and obtain the coordinates. A while loop is used to assure getting coordinate values
'''
for idx, row in toronto.iterrows():
    pc = row['Postcode']
    coords = None
    while coords is None:
        g = geocoder.google('{}, Toronto, Ontario'.format(str(pc)))
        coords = g.latlng
    toronto.at[idx, 'Latitude'] = coords[0]
    toronto.at[idx, 'Longitude'] = coords[1]
    
'''
# Out:
# "\nfor idx, row in toronto.iterrows():\n    pc = row['Postcode']\n    coords = None\n    while coords is None:\n        g = geocoder.google('{}, Toronto, Ontario'.format(str(pc)))\n        coords = g.latlng\n    toronto.at[idx, 'Latitude'] = coords[0]\n    toronto.at[idx, 'Longitude'] = coords[1]\n    \n"

# %% [markdown]
# Due to problems with obtaining coordinates from Geocoder the provided csv file is used to gather coordinates

# %%
toronto_ll = pd.read_csv('./assignment_files/Geospatial_Coordinates.csv')

# %%
# rename column name to 'Postcode'
toronto_ll = toronto_ll.rename(columns={'Postal Code':'Postcode'})

# %%
# join the dataframes on the postcode
toronto = toronto.merge(toronto_ll, how='inner', on='Postcode')

# %%
toronto.head()
# Out:
#   Postcode      Borough                           Neighbourhood   Latitude  \
# 0      M1B  Scarborough                          Rouge, Malvern  43.806686
# 1      M1C  Scarborough  Highland Creek, Rouge Hill, Port Union  43.784535
# 2      M1E  Scarborough       Guildwood, Morningside, West Hill  43.763573
# 3      M1G  Scarborough                                  Woburn  43.770992
# 4      M1H  Scarborough                               Cedarbrae  43.773136
#
#    Longitude
# 0 -79.194353
# 1 -79.160497
# 2 -79.188711
# 3 -79.216917
# 4 -79.239476

# %%
toronto.shape
# Out:
# (103, 5)

# %% [markdown]
# ## Explore venues in the neighbourhoods and cluster the neighbourhoods with k-Means clustering

# %%
address = 'Toronto'

geolocator = Nominatim(user_agent='Toronto-assignment')
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.653963, -79.387207.

# %% [markdown]
# ### Read in csv file with toronto values aquired with the foursquare API

# %%
toronto_venues = pd.read_csv('./assignment_files/toronto_venues.csv')

# %%
toronto_venues.groupby('Neighbourhood').count()
# Out:
#                                                     Neighbourhood Latitude  \
# Neighbourhood
# Adelaide, King, Richmond                                               100
# Agincourt                                                                4
# Agincourt North, L'Amoreaux East, Milliken, Ste...                       2
# Albion Gardens, Beaumond Heights, Humbergate, J...                      12
# Alderwood, Long Branch                                                  10
# Bathurst Manor, Downsview North, Wilson Heights                         16
# Bayview Village                                                          4
# Bedford Park, Lawrence Manor East                                       25
# Berczy Park                                                             54
# Birch Cliff, Cliffside West                                              4
# Bloordale Gardens, Eringate, Markland Wood, Old...                       7
# Brockton, Exhibition Place, Parkdale Village                            18
# Business reply mail Processing Centre969 Eastern                        17
# CFB Toronto, Downsview East                                              4
# CN Tower, Bathurst Quay, Island airport, Harbou...                      13
# Cabbagetown, St. James Town                                             49
# Caledonia-Fairbanks                                                      6
# Canada Post Gateway Processing Centre                                   10
# Cedarbrae                                                                8
# Central Bay Street                                                      81
# Chinatown, Grange Park, Kensington Market                               97
# Christie                                                                16
# Church and Wellesley                                                    85
# Clairlea, Golden Mile, Oakridge                                          9
# Clarks Corners, Sullivan, Tam O'Shanter                                 10
# Cliffcrest, Cliffside, Scarborough Village West                          3
# Cloverdale, Islington, Martin Grove, Princess G...                       1
# Commerce Court, Victoria Hotel                                         100
# Davisville                                                              35
# Davisville North                                                         7
# Deer Park, Forest Hill SE, Rathnelly, South Hil...                      15
# Del Ray, Keelesdale, Mount Dennis, Silverthorn                           4
# Design Exchange, Toronto Dominion Centre                               100
# Don Mills North                                                          6
# Dorset Park, Scarborough Town Centre, Wexford H...                       8
# Dovercourt Village, Dufferin                                            21
# Downsview Central                                                        4
# Downsview Northwest                                                      5
# Downsview West                                                           4
# East Birchmount Park, Ionview, Kennedy Park                              6
# East Toronto                                                             4
# Emery, Humberlea                                                         1
# Fairview, Henry Farm, Oriole                                            56
# First Canadian Place, Underground city                                 100
# Flemingdon Park, Don Mills South                                        20
# Forest Hill North, Forest Hill West                                      4
# Glencairn                                                                4
# Guildwood, Morningside, West Hill                                        6
# Harbord, University of Toronto                                          35
# Harbourfront East, Toronto Islands, Union Station                      100
# Harbourfront, Regent Park                                               49
# High Park, The Junction South                                           23
# Highland Creek, Rouge Hill, Port Union                                   3
# Hillcrest Village                                                        5
# Humber Bay Shores, Mimico South, New Toronto                            16
# Humber Bay, King's Mill Park, Kingsway Park Sou...                       3
# Humber Summit                                                            2
# Humewood-Cedarvale                                                       4
# Kingsview Village, Martin Grove Gardens, Richvi...                       3
# Kingsway Park South West, Mimico NW, The Queens...                      13
# L'Amoreaux West, Steeles West                                           13
# Lawrence Heights, Lawrence Manor                                        13
# Lawrence Park                                                            4
# Leaside                                                                 32
# Little Portugal, Trinity                                                63
# Maple Leaf Park, North Park, Upwood Park                                 4
# Maryvale, Wexford                                                        4
# Moore Park, Summerhill East                                              3
# North Toronto West                                                      21
# Northwest                                                                2
# Northwood Park, York University                                          4
# Parkdale, Roncesvalles                                                  16
# Parkwoods                                                                3
# Queen's Park                                                            45
# Rosedale                                                                 4
# Roselawn                                                                 4
# Rouge, Malvern                                                           2
# Runnymede, Swansea                                                      40
# Ryerson, Garden District                                               100
# Scarborough Village                                                      2
# Silver Hills, York Mills                                                 1
# St. James Town                                                         100
# Stn A PO Boxes 25 The Esplanade                                         96
# Studio District                                                         39
# The Annex, North Midtown, Yorkville                                     25
# The Beaches                                                              4
# The Beaches West, India Bazaar                                          17
# The Danforth West, Riverdale                                            42
# The Junction North, Runnymede                                            3
# The Kingsway, Montgomery Road, Old Mill North                            3
# Thorncliffe Park                                                        15
# Victoria Village                                                         4
# Westmount                                                                6
# Weston                                                                   2
# Willowdale South                                                        34
# Willowdale West                                                          5
# Woburn                                                                   4
# Woodbine Gardens, Parkview Hill                                         14
# Woodbine Heights                                                         9
# York Mills West                                                          3
#
#                                                     Neighbourhood Longitude  \
# Neighbourhood
# Adelaide, King, Richmond                                                100
# Agincourt                                                                 4
# Agincourt North, L'Amoreaux East, Milliken, Ste...                        2
# Albion Gardens, Beaumond Heights, Humbergate, J...                       12
# Alderwood, Long Branch                                                   10
# Bathurst Manor, Downsview North, Wilson Heights                          16
# Bayview Village                                                           4
# Bedford Park, Lawrence Manor East                                        25
# Berczy Park                                                              54
# Birch Cliff, Cliffside West                                               4
# Bloordale Gardens, Eringate, Markland Wood, Old...                        7
# Brockton, Exhibition Place, Parkdale Village                             18
# Business reply mail Processing Centre969 Eastern                         17
# CFB Toronto, Downsview East                                               4
# CN Tower, Bathurst Quay, Island airport, Harbou...                       13
# Cabbagetown, St. James Town                                              49
# Caledonia-Fairbanks                                                       6
# Canada Post Gateway Processing Centre                                    10
# Cedarbrae                                                                 8
# Central Bay Street                                                       81
# Chinatown, Grange Park, Kensington Market                                97
# Christie                                                                 16
# Church and Wellesley                                                     85
# Clairlea, Golden Mile, Oakridge                                           9
# Clarks Corners, Sullivan, Tam O'Shanter                                  10
# Cliffcrest, Cliffside, Scarborough Village West                           3
# Cloverdale, Islington, Martin Grove, Princess G...                        1
# Commerce Court, Victoria Hotel                                          100
# Davisville                                                               35
# Davisville North                                                          7
# Deer Park, Forest Hill SE, Rathnelly, South Hil...                       15
# Del Ray, Keelesdale, Mount Dennis, Silverthorn                            4
# Design Exchange, Toronto Dominion Centre                                100
# Don Mills North                                                           6
# Dorset Park, Scarborough Town Centre, Wexford H...                        8
# Dovercourt Village, Dufferin                                             21
# Downsview Central                                                         4
# Downsview Northwest                                                       5
# Downsview West                                                            4
# East Birchmount Park, Ionview, Kennedy Park                               6
# East Toronto                                                              4
# Emery, Humberlea                                                          1
# Fairview, Henry Farm, Oriole                                             56
# First Canadian Place, Underground city                                  100
# Flemingdon Park, Don Mills South                                         20
# Forest Hill North, Forest Hill West                                       4
# Glencairn                                                                 4
# Guildwood, Morningside, West Hill                                         6
# Harbord, University of Toronto                                           35
# Harbourfront East, Toronto Islands, Union Station                       100
# Harbourfront, Regent Park                                                49
# High Park, The Junction South                                            23
# Highland Creek, Rouge Hill, Port Union                                    3
# Hillcrest Village                                                         5
# Humber Bay Shores, Mimico South, New Toronto                             16
# Humber Bay, King's Mill Park, Kingsway Park Sou...                        3
# Humber Summit                                                             2
# Humewood-Cedarvale                                                        4
# Kingsview Village, Martin Grove Gardens, Richvi...                        3
# Kingsway Park South West, Mimico NW, The Queens...                       13
# L'Amoreaux West, Steeles West                                            13
# Lawrence Heights, Lawrence Manor                                         13
# Lawrence Park                                                             4
# Leaside                                                                  32
# Little Portugal, Trinity                                                 63
# Maple Leaf Park, North Park, Upwood Park                                  4
# Maryvale, Wexford                                                         4
# Moore Park, Summerhill East                                               3
# North Toronto West                                                       21
# Northwest                                                                 2
# Northwood Park, York University                                           4
# Parkdale, Roncesvalles                                                   16
# Parkwoods                                                                 3
# Queen's Park                                                             45
# Rosedale                                                                  4
# Roselawn                                                                  4
# Rouge, Malvern                                                            2
# Runnymede, Swansea                                                       40
# Ryerson, Garden District                                                100
# Scarborough Village                                                       2
# Silver Hills, York Mills                                                  1
# St. James Town                                                          100
# Stn A PO Boxes 25 The Esplanade                                          96
# Studio District                                                          39
# The Annex, North Midtown, Yorkville                                      25
# The Beaches                                                               4
# The Beaches West, India Bazaar                                           17
# The Danforth West, Riverdale                                             42
# The Junction North, Runnymede                                             3
# The Kingsway, Montgomery Road, Old Mill North                             3
# Thorncliffe Park                                                         15
# Victoria Village                                                          4
# Westmount                                                                 6
# Weston                                                                    2
# Willowdale South                                                         34
# Willowdale West                                                           5
# Woburn                                                                    4
# Woodbine Gardens, Parkview Hill                                          14
# Woodbine Heights                                                          9
# York Mills West                                                           3
#
#                                                     Venue  Venue Latitude  \
# Neighbourhood
# Adelaide, King, Richmond                              100             100
# Agincourt                                               4               4
# Agincourt North, L'Amoreaux East, Milliken, Ste...      2               2
# Albion Gardens, Beaumond Heights, Humbergate, J...     12              12
# Alderwood, Long Branch                                 10              10
# Bathurst Manor, Downsview North, Wilson Heights        16              16
# Bayview Village                                         4               4
# Bedford Park, Lawrence Manor East                      25              25
# Berczy Park                                            54              54
# Birch Cliff, Cliffside West                             4               4
# Bloordale Gardens, Eringate, Markland Wood, Old...      7               7
# Brockton, Exhibition Place, Parkdale Village           18              18
# Business reply mail Processing Centre969 Eastern       17              17
# CFB Toronto, Downsview East                             4               4
# CN Tower, Bathurst Quay, Island airport, Harbou...     13              13
# Cabbagetown, St. James Town                            49              49
# Caledonia-Fairbanks                                     6               6
# Canada Post Gateway Processing Centre                  10              10
# Cedarbrae                                               8               8
# Central Bay Street                                     81              81
# Chinatown, Grange Park, Kensington Market              97              97
# Christie                                               16              16
# Church and Wellesley                                   85              85
# Clairlea, Golden Mile, Oakridge                         9               9
# Clarks Corners, Sullivan, Tam O'Shanter                10              10
# Cliffcrest, Cliffside, Scarborough Village West         3               3
# Cloverdale, Islington, Martin Grove, Princess G...      1               1
# Commerce Court, Victoria Hotel                        100             100
# Davisville                                             35              35
# Davisville North                                        7               7
# Deer Park, Forest Hill SE, Rathnelly, South Hil...     15              15
# Del Ray, Keelesdale, Mount Dennis, Silverthorn          4               4
# Design Exchange, Toronto Dominion Centre              100             100
# Don Mills North                                         6               6
# Dorset Park, Scarborough Town Centre, Wexford H...      8               8
# Dovercourt Village, Dufferin                           21              21
# Downsview Central                                       4               4
# Downsview Northwest                                     5               5
# Downsview West                                          4               4
# East Birchmount Park, Ionview, Kennedy Park             6               6
# East Toronto                                            4               4
# Emery, Humberlea                                        1               1
# Fairview, Henry Farm, Oriole                           56              56
# First Canadian Place, Underground city                100             100
# Flemingdon Park, Don Mills South                       20              20
# Forest Hill North, Forest Hill West                     4               4
# Glencairn                                               4               4
# Guildwood, Morningside, West Hill                       6               6
# Harbord, University of Toronto                         35              35
# Harbourfront East, Toronto Islands, Union Station     100             100
# Harbourfront, Regent Park                              49              49
# High Park, The Junction South                          23              23
# Highland Creek, Rouge Hill, Port Union                  3               3
# Hillcrest Village                                       5               5
# Humber Bay Shores, Mimico South, New Toronto           16              16
# Humber Bay, King's Mill Park, Kingsway Park Sou...      3               3
# Humber Summit                                           2               2
# Humewood-Cedarvale                                      4               4
# Kingsview Village, Martin Grove Gardens, Richvi...      3               3
# Kingsway Park South West, Mimico NW, The Queens...     13              13
# L'Amoreaux West, Steeles West                          13              13
# Lawrence Heights, Lawrence Manor                       13              13
# Lawrence Park                                           4               4
# Leaside                                                32              32
# Little Portugal, Trinity                               63              63
# Maple Leaf Park, North Park, Upwood Park                4               4
# Maryvale, Wexford                                       4               4
# Moore Park, Summerhill East                             3               3
# North Toronto West                                     21              21
# Northwest                                               2               2
# Northwood Park, York University                         4               4
# Parkdale, Roncesvalles                                 16              16
# Parkwoods                                               3               3
# Queen's Park                                           45              45
# Rosedale                                                4               4
# Roselawn                                                4               4
# Rouge, Malvern                                          2               2
# Runnymede, Swansea                                     40              40
# Ryerson, Garden District                              100             100
# Scarborough Village                                     2               2
# Silver Hills, York Mills                                1               1
# St. James Town                                        100             100
# Stn A PO Boxes 25 The Esplanade                        96              96
# Studio District                                        39              39
# The Annex, North Midtown, Yorkville                    25              25
# The Beaches                                             4               4
# The Beaches West, India Bazaar                         17              17
# The Danforth West, Riverdale                           42              42
# The Junction North, Runnymede                           3               3
# The Kingsway, Montgomery Road, Old Mill North           3               3
# Thorncliffe Park                                       15              15
# Victoria Village                                        4               4
# Westmount                                               6               6
# Weston                                                  2               2
# Willowdale South                                       34              34
# Willowdale West                                         5               5
# Woburn                                                  4               4
# Woodbine Gardens, Parkview Hill                        14              14
# Woodbine Heights                                        9               9
# York Mills West                                         3               3
#
#                                                     Venue Longitude  \
# Neighbourhood
# Adelaide, King, Richmond                                        100
# Agincourt                                                         4
# Agincourt North, L'Amoreaux East, Milliken, Ste...                2
# Albion Gardens, Beaumond Heights, Humbergate, J...               12
# Alderwood, Long Branch                                           10
# Bathurst Manor, Downsview North, Wilson Heights                  16
# Bayview Village                                                   4
# Bedford Park, Lawrence Manor East                                25
# Berczy Park                                                      54
# Birch Cliff, Cliffside West                                       4
# Bloordale Gardens, Eringate, Markland Wood, Old...                7
# Brockton, Exhibition Place, Parkdale Village                     18
# Business reply mail Processing Centre969 Eastern                 17
# CFB Toronto, Downsview East                                       4
# CN Tower, Bathurst Quay, Island airport, Harbou...               13
# Cabbagetown, St. James Town                                      49
# Caledonia-Fairbanks                                               6
# Canada Post Gateway Processing Centre                            10
# Cedarbrae                                                         8
# Central Bay Street                                               81
# Chinatown, Grange Park, Kensington Market                        97
# Christie                                                         16
# Church and Wellesley                                             85
# Clairlea, Golden Mile, Oakridge                                   9
# Clarks Corners, Sullivan, Tam O'Shanter                          10
# Cliffcrest, Cliffside, Scarborough Village West                   3
# Cloverdale, Islington, Martin Grove, Princess G...                1
# Commerce Court, Victoria Hotel                                  100
# Davisville                                                       35
# Davisville North                                                  7
# Deer Park, Forest Hill SE, Rathnelly, South Hil...               15
# Del Ray, Keelesdale, Mount Dennis, Silverthorn                    4
# Design Exchange, Toronto Dominion Centre                        100
# Don Mills North                                                   6
# Dorset Park, Scarborough Town Centre, Wexford H...                8
# Dovercourt Village, Dufferin                                     21
# Downsview Central                                                 4
# Downsview Northwest                                               5
# Downsview West                                                    4
# East Birchmount Park, Ionview, Kennedy Park                       6
# East Toronto                                                      4
# Emery, Humberlea                                                  1
# Fairview, Henry Farm, Oriole                                     56
# First Canadian Place, Underground city                          100
# Flemingdon Park, Don Mills South                                 20
# Forest Hill North, Forest Hill West                               4
# Glencairn                                                         4
# Guildwood, Morningside, West Hill                                 6
# Harbord, University of Toronto                                   35
# Harbourfront East, Toronto Islands, Union Station               100
# Harbourfront, Regent Park                                        49
# High Park, The Junction South                                    23
# Highland Creek, Rouge Hill, Port Union                            3
# Hillcrest Village                                                 5
# Humber Bay Shores, Mimico South, New Toronto                     16
# Humber Bay, King's Mill Park, Kingsway Park Sou...                3
# Humber Summit                                                     2
# Humewood-Cedarvale                                                4
# Kingsview Village, Martin Grove Gardens, Richvi...                3
# Kingsway Park South West, Mimico NW, The Queens...               13
# L'Amoreaux West, Steeles West                                    13
# Lawrence Heights, Lawrence Manor                                 13
# Lawrence Park                                                     4
# Leaside                                                          32
# Little Portugal, Trinity                                         63
# Maple Leaf Park, North Park, Upwood Park                          4
# Maryvale, Wexford                                                 4
# Moore Park, Summerhill East                                       3
# North Toronto West                                               21
# Northwest                                                         2
# Northwood Park, York University                                   4
# Parkdale, Roncesvalles                                           16
# Parkwoods                                                         3
# Queen's Park                                                     45
# Rosedale                                                          4
# Roselawn                                                          4
# Rouge, Malvern                                                    2
# Runnymede, Swansea                                               40
# Ryerson, Garden District                                        100
# Scarborough Village                                               2
# Silver Hills, York Mills                                          1
# St. James Town                                                  100
# Stn A PO Boxes 25 The Esplanade                                  96
# Studio District                                                  39
# The Annex, North Midtown, Yorkville                              25
# The Beaches                                                       4
# The Beaches West, India Bazaar                                   17
# The Danforth West, Riverdale                                     42
# The Junction North, Runnymede                                     3
# The Kingsway, Montgomery Road, Old Mill North                     3
# Thorncliffe Park                                                 15
# Victoria Village                                                  4
# Westmount                                                         6
# Weston                                                            2
# Willowdale South                                                 34
# Willowdale West                                                   5
# Woburn                                                            4
# Woodbine Gardens, Parkview Hill                                  14
# Woodbine Heights                                                  9
# York Mills West                                                   3
#
#                                                     Venue Category
# Neighbourhood
# Adelaide, King, Richmond                                       100
# Agincourt                                                        4
# Agincourt North, L'Amoreaux East, Milliken, Ste...               2
# Albion Gardens, Beaumond Heights, Humbergate, J...              12
# Alderwood, Long Branch                                          10
# Bathurst Manor, Downsview North, Wilson Heights                 16
# Bayview Village                                                  4
# Bedford Park, Lawrence Manor East                               25
# Berczy Park                                                     54
# Birch Cliff, Cliffside West                                      4
# Bloordale Gardens, Eringate, Markland Wood, Old...               7
# Brockton, Exhibition Place, Parkdale Village                    18
# Business reply mail Processing Centre969 Eastern                17
# CFB Toronto, Downsview East                                      4
# CN Tower, Bathurst Quay, Island airport, Harbou...              13
# Cabbagetown, St. James Town                                     49
# Caledonia-Fairbanks                                              6
# Canada Post Gateway Processing Centre                           10
# Cedarbrae                                                        8
# Central Bay Street                                              81
# Chinatown, Grange Park, Kensington Market                       97
# Christie                                                        16
# Church and Wellesley                                            85
# Clairlea, Golden Mile, Oakridge                                  9
# Clarks Corners, Sullivan, Tam O'Shanter                         10
# Cliffcrest, Cliffside, Scarborough Village West                  3
# Cloverdale, Islington, Martin Grove, Princess G...               1
# Commerce Court, Victoria Hotel                                 100
# Davisville                                                      35
# Davisville North                                                 7
# Deer Park, Forest Hill SE, Rathnelly, South Hil...              15
# Del Ray, Keelesdale, Mount Dennis, Silverthorn                   4
# Design Exchange, Toronto Dominion Centre                       100
# Don Mills North                                                  6
# Dorset Park, Scarborough Town Centre, Wexford H...               8
# Dovercourt Village, Dufferin                                    21
# Downsview Central                                                4
# Downsview Northwest                                              5
# Downsview West                                                   4
# East Birchmount Park, Ionview, Kennedy Park                      6
# East Toronto                                                     4
# Emery, Humberlea                                                 1
# Fairview, Henry Farm, Oriole                                    56
# First Canadian Place, Underground city                         100
# Flemingdon Park, Don Mills South                                20
# Forest Hill North, Forest Hill West                              4
# Glencairn                                                        4
# Guildwood, Morningside, West Hill                                6
# Harbord, University of Toronto                                  35
# Harbourfront East, Toronto Islands, Union Station              100
# Harbourfront, Regent Park                                       49
# High Park, The Junction South                                   23
# Highland Creek, Rouge Hill, Port Union                           3
# Hillcrest Village                                                5
# Humber Bay Shores, Mimico South, New Toronto                    16
# Humber Bay, King's Mill Park, Kingsway Park Sou...               3
# Humber Summit                                                    2
# Humewood-Cedarvale                                               4
# Kingsview Village, Martin Grove Gardens, Richvi...               3
# Kingsway Park South West, Mimico NW, The Queens...              13
# L'Amoreaux West, Steeles West                                   13
# Lawrence Heights, Lawrence Manor                                13
# Lawrence Park                                                    4
# Leaside                                                         32
# Little Portugal, Trinity                                        63
# Maple Leaf Park, North Park, Upwood Park                         4
# Maryvale, Wexford                                                4
# Moore Park, Summerhill East                                      3
# North Toronto West                                              21
# Northwest                                                        2
# Northwood Park, York University                                  4
# Parkdale, Roncesvalles                                          16
# Parkwoods                                                        3
# Queen's Park                                                    45
# Rosedale                                                         4
# Roselawn                                                         4
# Rouge, Malvern                                                   2
# Runnymede, Swansea                                              40
# Ryerson, Garden District                                       100
# Scarborough Village                                              2
# Silver Hills, York Mills                                         1
# St. James Town                                                 100
# Stn A PO Boxes 25 The Esplanade                                 96
# Studio District                                                 39
# The Annex, North Midtown, Yorkville                             25
# The Beaches                                                      4
# The Beaches West, India Bazaar                                  17
# The Danforth West, Riverdale                                    42
# The Junction North, Runnymede                                    3
# The Kingsway, Montgomery Road, Old Mill North                    3
# Thorncliffe Park                                                15
# Victoria Village                                                 4
# Westmount                                                        6
# Weston                                                           2
# Willowdale South                                                34
# Willowdale West                                                  5
# Woburn                                                           4
# Woodbine Gardens, Parkview Hill                                 14
# Woodbine Heights                                                 9
# York Mills West                                                  3

# %%
print('There are {} uniques categories.'.format(len(toronto_venues['Venue Category'].unique())))
# Out:
# There are 268 uniques categories.

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix='', prefix_sep='')

# add neighborhood column back to dataframe
toronto_onehot['Neighbourhood'] = toronto_venues['Neighbourhood'] 

# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

# %%
toronto_grouped = toronto_onehot.groupby('Neighbourhood').mean().reset_index()

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighbourhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighbourhoods_venues_sorted = pd.DataFrame(columns=columns)
neighbourhoods_venues_sorted['Neighbourhood'] = toronto_grouped['Neighbourhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighbourhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

# %% [markdown]
# ### Cluster neighbourhoods

# %%
# set number of clusters
kclusters = 4

toronto_grouped_clustering = toronto_grouped.drop('Neighbourhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_
# Out:
# array([3, 3, 0, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 0, 3, 3, 0, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 0, 3, 3, 3,
#        3, 3, 0, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 0, 3, 3, 3, 0, 3, 3, 0,
#        3, 3, 3, 3, 3, 3, 0, 3, 0, 3, 3, 3, 3, 3, 1, 3, 3, 3, 3, 3, 3, 3,
#        3, 0, 3, 3, 3, 0, 3, 3, 3, 3, 3, 0], dtype=int32)

# %%
kmeans.labels_.shape
# Out:
# (100,)

# %%
# add clustering labels
toronto_merged = toronto.merge(neighbourhoods_venues_sorted, how='inner', on='Neighbourhood')
toronto_merged['Cluster Labels'] = kmeans.labels_

toronto_merged.head()
# Out:
#   Postcode      Borough                           Neighbourhood   Latitude  \
# 0      M1B  Scarborough                          Rouge, Malvern  43.806686
# 1      M1C  Scarborough  Highland Creek, Rouge Hill, Port Union  43.784535
# 2      M1E  Scarborough       Guildwood, Morningside, West Hill  43.763573
# 3      M1G  Scarborough                                  Woburn  43.770992
# 4      M1H  Scarborough                               Cedarbrae  43.773136
#
#    Longitude 1st Most Common Venue       2nd Most Common Venue  \
# 0 -79.194353            Print Shop        Fast Food Restaurant
# 1 -79.160497           Golf Course  Construction & Landscaping
# 2 -79.188711    Mexican Restaurant                 Pizza Place
# 3 -79.216917           Coffee Shop           Korean Restaurant
# 4 -79.239476    Athletics & Sports            Hakka Restaurant
#
#   3rd Most Common Venue        4th Most Common Venue 5th Most Common Venue  \
# 0    Falafel Restaurant                  Event Space  Ethiopian Restaurant
# 1                   Bar  Eastern European Restaurant               Dog Run
# 2   Rental Car Location            Electronics Store        Breakfast Spot
# 3      Insurance Office  Eastern European Restaurant        Discount Store
# 4                Lounge                       Bakery  Caribbean Restaurant
#
#   6th Most Common Venue 7th Most Common Venue        8th Most Common Venue  \
# 0   Empanada Restaurant     Electronics Store  Eastern European Restaurant
# 1      Doner Restaurant            Donut Shop                    Drugstore
# 2        Medical Center           Yoga Studio               Discount Store
# 3               Dog Run      Doner Restaurant                   Donut Shop
# 4                  Bank       Thai Restaurant          Fried Chicken Joint
#
#   9th Most Common Venue 10th Most Common Venue  Cluster Labels
# 0    Dim Sum Restaurant    Dumpling Restaurant               3
# 1   Dumpling Restaurant            Yoga Studio               3
# 2               Dog Run       Doner Restaurant               0
# 3             Drugstore    Dumpling Restaurant               3
# 4             Drugstore       Doner Restaurant               3

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
rainbow = ['cyan', 'green', 'red', 'blue']

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighbourhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster],
        fill=True,
        fill_color=rainbow[cluster],
        fill_opacity=0.4).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Cluster 0

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 0, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#              Borough       1st Most Common Venue 2nd Most Common Venue  \
# 2        Scarborough          Mexican Restaurant           Pizza Place
# 13       Scarborough                 Pizza Place              Pharmacy
# 16        North York        Fast Food Restaurant               Dog Run
# 40      East Toronto                         Gym  Fast Food Restaurant
# 46   Central Toronto                  Restaurant            Playground
# 58  Downtown Toronto                 Coffee Shop                  Café
# 62   Central Toronto            Sushi Restaurant              Bus Line
# 65  Downtown Toronto                        Café                   Bar
# 72              York                        Park              Pharmacy
# 74      West Toronto              Discount Store              Pharmacy
# 89         Etobicoke  Construction & Landscaping        Breakfast Spot
# 93        North York                 Pizza Place   Empanada Restaurant
# 99         Etobicoke                   Drugstore   Rental Car Location
#
#        3rd Most Common Venue          4th Most Common Venue  \
# 2        Rental Car Location              Electronics Store
# 13      Fast Food Restaurant             Italian Restaurant
# 16  Mediterranean Restaurant                           Pool
# 40          Sushi Restaurant                     Steakhouse
# 46                       Gym                    Yoga Studio
# 58                     Hotel                     Restaurant
# 62                     Trail                  Jewelry Store
# 65     Vietnamese Restaurant  Vegetarian / Vegan Restaurant
# 72                    Market           Fast Food Restaurant
# 74               Supermarket                         Bakery
# 89            Baseball Field                    Yoga Studio
# 93              Dessert Shop             Falafel Restaurant
# 99               Yoga Studio                          Diner
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 2         Breakfast Spot        Medical Center           Yoga Studio
# 13          Noodle House         Shopping Mall   Fried Chicken Joint
# 16           Golf Course             Drugstore                 Diner
# 40        Ice Cream Shop    Italian Restaurant                   Pub
# 46             Drugstore                 Diner        Discount Store
# 58   American Restaurant                   Gym         Deli / Bodega
# 62           Yoga Studio                 Diner               Dog Run
# 65           Coffee Shop                Bakery    Mexican Restaurant
# 72         Women's Store                   Gym          Dessert Shop
# 74  Gym / Fitness Center                  Pool            Smoke Shop
# 89     Electronics Store      Doner Restaurant            Donut Shop
# 93           Event Space  Ethiopian Restaurant     Electronics Store
# 99        Discount Store               Dog Run      Doner Restaurant
#
#           8th Most Common Venue 9th Most Common Venue  \
# 2                Discount Store               Dog Run
# 13           Chinese Restaurant       Thai Restaurant
# 16               Discount Store      Doner Restaurant
# 40            Fish & Chips Shop         Burrito Place
# 46                      Dog Run      Doner Restaurant
# 58                    Gastropub    Italian Restaurant
# 62             Doner Restaurant            Donut Shop
# 65           Chinese Restaurant   Dumpling Restaurant
# 72                  Event Space  Ethiopian Restaurant
# 74                      Brewery  Fast Food Restaurant
# 89                    Drugstore   Dumpling Restaurant
# 93  Eastern European Restaurant   Dumpling Restaurant
# 99                   Donut Shop   Dumpling Restaurant
#
#          10th Most Common Venue  Cluster Labels
# 2              Doner Restaurant               0
# 13             Doner Restaurant               0
# 16                   Donut Shop               0
# 40               Sandwich Place               0
# 46                   Donut Shop               0
# 58          Japanese Restaurant               0
# 62                    Drugstore               0
# 65                 Burger Joint               0
# 72          Empanada Restaurant               0
# 74                          Bar               0
# 89  Eastern European Restaurant               0
# 93                    Drugstore               0
# 99                 Dessert Shop               0

# %% [markdown]
# ### Cluster 1

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 1, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#          Borough 1st Most Common Venue 2nd Most Common Venue  \
# 80  West Toronto                  Café    Mexican Restaurant
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 80   Fried Chicken Joint             Gastropub                   Bar
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 80                 Diner                Bakery             Speakeasy
#
#      9th Most Common Venue 10th Most Common Venue  Cluster Labels
# 80  Furniture / Home Store            Flea Market               1

# %% [markdown]
# ### Cluster 2

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 2, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#         Borough 1st Most Common Venue 2nd Most Common Venue  \
# 6   Scarborough        Discount Store         Train Station
# 26   North York           Coffee Shop              Pharmacy
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 6       Department Store           Bus Station           Coffee Shop
# 26         Deli / Bodega         Shopping Mall  Fast Food Restaurant
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 6                Dog Run      Doner Restaurant            Donut Shop
# 26           Bridal Shop        Sandwich Place                 Diner
#
#    9th Most Common Venue 10th Most Common Venue  Cluster Labels
# 6              Drugstore            Yoga Studio               2
# 26                  Bank             Restaurant               2

# %% [markdown]
# ### Cluster 3

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 3, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#              Borough   1st Most Common Venue       2nd Most Common Venue  \
# 0        Scarborough              Print Shop        Fast Food Restaurant
# 1        Scarborough             Golf Course  Construction & Landscaping
# 3        Scarborough             Coffee Shop           Korean Restaurant
# 4        Scarborough      Athletics & Sports            Hakka Restaurant
# 5        Scarborough              Playground           Convenience Store
# 7        Scarborough                Bus Line                      Bakery
# 8        Scarborough           Movie Theater         American Restaurant
# 9        Scarborough         College Stadium                        Café
# 10       Scarborough       Indian Restaurant      Furniture / Home Store
# 11       Scarborough              Smoke Shop   Middle Eastern Restaurant
# 12       Scarborough                  Lounge                Skating Rink
# 14       Scarborough              Playground                        Park
# 15       Scarborough      Chinese Restaurant        Fast Food Restaurant
# 17        North York          Clothing Store        Fast Food Restaurant
# 18        North York                    Café         Japanese Restaurant
# 19        North York               Cafeteria          Dim Sum Restaurant
# 20        North York        Ramen Restaurant                  Restaurant
# 21        North York                    Park                        Bank
# 22        North York                Pharmacy               Grocery Store
# 23        North York    Fast Food Restaurant                        Park
# 24        North York                    Café              Baseball Field
# 25        North York              Beer Store                         Gym
# 27        North York  Furniture / Home Store              Massage Studio
# 28        North York                    Park                     Airport
# 29        North York           Moving Target               Grocery Store
# 30        North York       Korean Restaurant              Baseball Field
# 31        North York      Athletics & Sports        Gym / Fitness Center
# 32        North York             Coffee Shop                Hockey Arena
# 33         East York    Fast Food Restaurant                 Pizza Place
# 34         East York            Skating Rink                    Pharmacy
# 35      East Toronto             Coffee Shop                         Pub
# 36         East York     Sporting Goods Shop                 Coffee Shop
# 37         East York       Indian Restaurant                 Pizza Place
# 38         East York                    Park               Metro Station
# 39      East Toronto        Greek Restaurant                 Coffee Shop
# 41      East Toronto                    Café                 Coffee Shop
# 42   Central Toronto      Dim Sum Restaurant                        Park
# 43   Central Toronto                    Park              Breakfast Spot
# 44   Central Toronto          Clothing Store         Sporting Goods Shop
# 45   Central Toronto            Dessert Shop              Sandwich Place
# 47   Central Toronto             Coffee Shop                         Pub
# 48  Downtown Toronto                    Park                  Playground
# 49  Downtown Toronto             Coffee Shop                  Restaurant
# 50  Downtown Toronto     Japanese Restaurant            Sushi Restaurant
# 51  Downtown Toronto             Coffee Shop                        Café
# 52  Downtown Toronto             Coffee Shop              Clothing Store
# 53  Downtown Toronto             Coffee Shop                  Restaurant
# 54  Downtown Toronto             Coffee Shop                  Restaurant
# 55  Downtown Toronto             Coffee Shop                        Café
# 56  Downtown Toronto             Coffee Shop                        Café
# 57  Downtown Toronto             Coffee Shop                       Hotel
# 59  Downtown Toronto             Coffee Shop                        Café
# 60        North York             Coffee Shop          Italian Restaurant
# 61   Central Toronto                  Garden                 Music Venue
# 63   Central Toronto          Sandwich Place                        Café
# 64  Downtown Toronto                    Café                 Coffee Shop
# 66  Downtown Toronto          Airport Lounge            Airport Terminal
# 67  Downtown Toronto             Coffee Shop                  Restaurant
# 68  Downtown Toronto             Coffee Shop                        Café
# 69        North York          Clothing Store      Furniture / Home Store
# 70        North York                     Pub                        Park
# 71              York                   Field                     Dog Run
# 73  Downtown Toronto                    Café               Grocery Store
# 75      West Toronto                     Bar                  Restaurant
# 76      West Toronto          Breakfast Spot                 Coffee Shop
# 77        North York        Basketball Court                        Park
# 78              York      Turkish Restaurant                 Coffee Shop
# 79              York             Pizza Place               Grocery Store
# 81      West Toronto          Breakfast Spot                   Gift Shop
# 82      West Toronto             Coffee Shop                 Pizza Place
# 83      Queen's Park             Coffee Shop                         Gym
# 84       Mississauga                   Hotel                 Coffee Shop
# 85      East Toronto      Light Rail Station                  Skate Park
# 86         Etobicoke                    Café                    Pharmacy
# 87         Etobicoke             Pizza Place                    Pharmacy
# 88         Etobicoke                    Park                       River
# 90         Etobicoke          Discount Store                Burger Joint
# 91         Etobicoke                    Bank                 Yoga Studio
# 92         Etobicoke                Pharmacy                  Beer Store
# 94        North York          Baseball Field           Electronics Store
# 95              York                    Park           Convenience Store
# 96         Etobicoke            Intersection   Middle Eastern Restaurant
# 97         Etobicoke             Pizza Place                        Park
# 98         Etobicoke           Grocery Store                    Pharmacy
#
#           3rd Most Common Venue        4th Most Common Venue  \
# 0            Falafel Restaurant                  Event Space
# 1                           Bar  Eastern European Restaurant
# 3              Insurance Office  Eastern European Restaurant
# 4                        Lounge                       Bakery
# 5                   Yoga Studio          Dumpling Restaurant
# 7                          Park                 Soccer Field
# 8                         Motel                    Drugstore
# 9                  Skating Rink        General Entertainment
# 10           Chinese Restaurant                    Pet Store
# 11               Breakfast Spot                       Bakery
# 12               Clothing Store               Breakfast Spot
# 14                  Yoga Studio          Dumpling Restaurant
# 15                     Pharmacy                  Coffee Shop
# 17                  Coffee Shop                   Restaurant
# 18                         Bank           Chinese Restaurant
# 19               Farmers Market           Falafel Restaurant
# 20                  Pizza Place               Sandwich Place
# 21                  Yoga Studio  Eastern European Restaurant
# 22                  Coffee Shop                      Butcher
# 23            Food & Drink Shop          Dumpling Restaurant
# 24          Japanese Restaurant         Caribbean Restaurant
# 25             Asian Restaurant                  Coffee Shop
# 27                  Coffee Shop                          Bar
# 28                     Bus Stop            Electronics Store
# 29                         Bank                Shopping Mall
# 30                   Food Truck             Business Service
# 31               Discount Store                Grocery Store
# 32        Portuguese Restaurant                 Intersection
# 33                     Pharmacy           Athletics & Sports
# 34             Asian Restaurant               Cosmetics Shop
# 35                 Neighborhood                  Yoga Studio
# 36                Grocery Store                 Burger Joint
# 37                 Burger Joint               Sandwich Place
# 38            Convenience Store                  Yoga Studio
# 39               Ice Cream Shop                    Bookstore
# 41           Italian Restaurant                       Bakery
# 42                  Swim School                     Bus Line
# 43               Sandwich Place                        Hotel
# 44                  Coffee Shop                  Yoga Studio
# 45                  Pizza Place           Seafood Restaurant
# 47                  Supermarket           Light Rail Station
# 48                        Trail                  Yoga Studio
# 49                         Café            Indian Restaurant
# 50                  Coffee Shop                      Gay Bar
# 51                       Bakery                          Pub
# 52                         Café               Cosmetics Shop
# 53                        Hotel                         Café
# 54                 Cocktail Bar               Farmers Market
# 55           Italian Restaurant               Ice Cream Shop
# 56                   Steakhouse              Thai Restaurant
# 57                     Aquarium                  Pizza Place
# 59                   Restaurant                        Hotel
# 60         Fast Food Restaurant             Greek Restaurant
# 61                         Pool                 Home Service
# 63                  Coffee Shop                  Pizza Place
# 64                          Bar                    Bookstore
# 66              Airport Service              Harbor / Marina
# 67           Seafood Restaurant                         Café
# 68                        Hotel                   Restaurant
# 69            Accessories Store           Athletics & Sports
# 70                  Pizza Place          Japanese Restaurant
# 71                 Hockey Arena                        Trail
# 73                         Park           Athletics & Sports
# 75                  Men's Store             Asian Restaurant
# 76                         Café                          Gym
# 77   Construction & Landscaping                       Bakery
# 78               Sandwich Place                          Bar
# 79                     Bus Line                  Yoga Studio
# 81                   Restaurant                Movie Theater
# 82                         Café             Sushi Restaurant
# 83          Japanese Restaurant                        Diner
# 84          American Restaurant         Gym / Fitness Center
# 85         Fast Food Restaurant             Recording Studio
# 86                       Bakery          Fried Chicken Joint
# 87                 Skating Rink               Sandwich Place
# 88                         Pool                  Yoga Studio
# 90                  Wings Joint                          Gym
# 91  Eastern European Restaurant                      Dog Run
# 92                  Pizza Place            Convenience Store
# 94                      Dog Run             Doner Restaurant
# 95                  Yoga Studio          Dumpling Restaurant
# 96                  Pizza Place                  Coffee Shop
# 97            Mobile Phone Shop                  Yoga Studio
# 98          Fried Chicken Joint                  Pizza Place
#
#         5th Most Common Venue        6th Most Common Venue  \
# 0        Ethiopian Restaurant          Empanada Restaurant
# 1                     Dog Run             Doner Restaurant
# 3              Discount Store                      Dog Run
# 4        Caribbean Restaurant                         Bank
# 5              Discount Store                      Dog Run
# 7               Metro Station                 Intersection
# 8                       Diner               Discount Store
# 9                  Donut Shop                        Diner
# 10      Vietnamese Restaurant           Light Rail Station
# 11                Yoga Studio          Dumpling Restaurant
# 12                Yoga Studio  Eastern European Restaurant
# 14                      Diner               Discount Store
# 15          Indian Restaurant               Sandwich Place
# 17                 Food Court                   Shoe Store
# 18                Yoga Studio               Discount Store
# 19                Event Space         Ethiopian Restaurant
# 20                       Café         Fast Food Restaurant
# 21                    Dog Run             Doner Restaurant
# 22                Pizza Place         Ethiopian Restaurant
# 23                      Diner               Discount Store
# 24           Basketball Court         Gym / Fitness Center
# 25      General Entertainment          Japanese Restaurant
# 27        Dumpling Restaurant               Discount Store
# 28                Yoga Studio                    Drugstore
# 29                Yoga Studio          Dumpling Restaurant
# 30       Ethiopian Restaurant          Empanada Restaurant
# 31               Liquor Store          Dumpling Restaurant
# 32                Yoga Studio                    Drugstore
# 33                  Gastropub                 Intersection
# 34                Curling Ice                   Beer Store
# 35             Discount Store                      Dog Run
# 36                 Restaurant                   Beer Store
# 37             Discount Store                         Bank
# 38                    Dog Run             Doner Restaurant
# 39         Italian Restaurant                  Yoga Studio
# 41        American Restaurant                  Fish Market
# 42        Dumpling Restaurant                      Dog Run
# 43          Food & Drink Shop                 Burger Joint
# 44        Rental Car Location         Fast Food Restaurant
# 45                Coffee Shop           Italian Restaurant
# 47      Vietnamese Restaurant             Sushi Restaurant
# 48                  Drugstore                        Diner
# 49                        Pub           Italian Restaurant
# 50                 Restaurant                 Burger Joint
# 51                       Park               Breakfast Spot
# 52  Middle Eastern Restaurant                      Theater
# 53                  Gastropub           Italian Restaurant
# 54                Cheese Shop                         Café
# 55             Sandwich Place                 Burger Joint
# 56        American Restaurant                   Restaurant
# 57                       Café                      Brewery
# 59        American Restaurant                    Gastropub
# 60                 Restaurant                      Butcher
# 61                 Donut Shop           Dim Sum Restaurant
# 63              Grocery Store                 Liquor Store
# 64                 Restaurant                       Bakery
# 66              Boat or Ferry             Sculpture Garden
# 67         Italian Restaurant                 Cocktail Bar
# 68        American Restaurant                    Gastropub
# 69                Event Space           Miscellaneous Shop
# 70                Yoga Studio                        Diner
# 71                Yoga Studio          Dumpling Restaurant
# 73                  Nightclub                   Restaurant
# 75                Coffee Shop                         Café
# 76                        Bar           Italian Restaurant
# 77          Electronics Store             Doner Restaurant
# 78        Dumpling Restaurant                      Dog Run
# 79                  Drugstore                        Diner
# 81               Burger Joint  Eastern European Restaurant
# 82          Electronics Store           Italian Restaurant
# 83           Sushi Restaurant                  Yoga Studio
# 84        Fried Chicken Joint     Mediterranean Restaurant
# 85              Auto Workshop                Burrito Place
# 86          Fish & Chips Shop         Fast Food Restaurant
# 87                        Pub                         Pool
# 88                  Drugstore                        Diner
# 90              Grocery Store         Fast Food Restaurant
# 91           Doner Restaurant                   Donut Shop
# 92                       Café                 Liquor Store
# 94                 Donut Shop                    Drugstore
# 95             Discount Store                      Dog Run
# 96             Sandwich Place           Chinese Restaurant
# 97                  Drugstore                        Diner
# 98                Coffee Shop               Discount Store
#
#         7th Most Common Venue        8th Most Common Venue  \
# 0           Electronics Store  Eastern European Restaurant
# 1                  Donut Shop                    Drugstore
# 3            Doner Restaurant                   Donut Shop
# 4             Thai Restaurant          Fried Chicken Joint
# 5            Doner Restaurant                   Donut Shop
# 7        Fast Food Restaurant              Coworking Space
# 8                     Dog Run             Doner Restaurant
# 9              Discount Store                      Dog Run
# 10  Latin American Restaurant                        Diner
# 11           Doner Restaurant                   Donut Shop
# 12                    Dog Run             Doner Restaurant
# 14                    Dog Run             Doner Restaurant
# 15        Japanese Restaurant                  Pizza Place
# 17                     Bakery                Shopping Mall
# 18           Doner Restaurant                   Donut Shop
# 19        Empanada Restaurant            Electronics Store
# 20                Coffee Shop          Arts & Crafts Store
# 21                 Donut Shop                    Drugstore
# 22        Empanada Restaurant                  Event Space
# 23                    Dog Run             Doner Restaurant
# 24       Ethiopian Restaurant          Empanada Restaurant
# 25         Italian Restaurant           Dim Sum Restaurant
# 27                    Dog Run             Doner Restaurant
# 28             Discount Store                      Dog Run
# 29                    Dog Run             Doner Restaurant
# 30          Electronics Store  Eastern European Restaurant
# 31                      Diner                      Dog Run
# 32                      Diner               Discount Store
# 33                  Pet Store                         Café
# 34                       Park                  Video Store
# 35           Doner Restaurant                   Donut Shop
# 36                  Bike Shop                Smoothie Shop
# 37                Supermarket          Housing Development
# 38                 Donut Shop                    Drugstore
# 39                    Brewery              Bubble Tea Shop
# 41                  Juice Bar                    Bookstore
# 42           Doner Restaurant                   Donut Shop
# 43                Pizza Place            Electronics Store
# 44                        Spa               Sandwich Place
# 45                       Café             Sushi Restaurant
# 47        Fried Chicken Joint            Convenience Store
# 48             Discount Store                      Dog Run
# 49                     Bakery           Chinese Restaurant
# 50            Bubble Tea Shop                    Gastropub
# 51                 Restaurant                      Theater
# 52            Thai Restaurant           Italian Restaurant
# 53         Seafood Restaurant               Clothing Store
# 54                        Pub           Seafood Restaurant
# 55                        Bar           Falafel Restaurant
# 56                      Hotel                       Bakery
# 57                 Restaurant               Scenic Lookout
# 59                     Bakery                Deli / Bodega
# 60                       Café                          Pub
# 61                      Diner               Discount Store
# 63               Burger Joint            Jewish Restaurant
# 64        Japanese Restaurant      Comfort Food Restaurant
# 66                   Boutique                 Airport Gate
# 67                        Pub                        Hotel
# 68              Deli / Bodega                          Gym
# 69                Coffee Shop                     Boutique
# 70             Discount Store                      Dog Run
# 71             Discount Store             Doner Restaurant
# 73                      Diner           Italian Restaurant
# 75               Cocktail Bar        Vietnamese Restaurant
# 76       Caribbean Restaurant                      Stadium
# 77                 Donut Shop                    Drugstore
# 78           Doner Restaurant                   Donut Shop
# 79             Discount Store                      Dog Run
# 81                        Bar                         Bank
# 82                        Bar                         Food
# 83         Chinese Restaurant                Smoothie Shop
# 84             Sandwich Place                Burrito Place
# 85                     Garden                Garden Center
# 86               Liquor Store           Mexican Restaurant
# 87         Athletics & Sports                          Gym
# 88             Discount Store                      Dog Run
# 90                     Bakery                  Social Club
# 91                  Drugstore          Dumpling Restaurant
# 92                       Park                  Golf Course
# 94        Dumpling Restaurant  Eastern European Restaurant
# 95           Doner Restaurant                   Donut Shop
# 96                      Diner               Discount Store
# 97             Discount Store                      Dog Run
# 98             Sandwich Place                 Liquor Store
#
#           9th Most Common Venue       10th Most Common Venue  Cluster Labels
# 0            Dim Sum Restaurant          Dumpling Restaurant               3
# 1           Dumpling Restaurant                  Yoga Studio               3
# 3                     Drugstore          Dumpling Restaurant               3
# 4                     Drugstore             Doner Restaurant               3
# 5                     Drugstore            Electronics Store               3
# 7                    Donut Shop               Farmers Market               3
# 8                    Donut Shop          Dumpling Restaurant               3
# 9              Doner Restaurant                    Drugstore               3
# 10               Discount Store                      Dog Run               3
# 11                    Drugstore            Electronics Store               3
# 12                   Donut Shop                    Drugstore               3
# 14                   Donut Shop                    Drugstore               3
# 15               Breakfast Spot                Grocery Store               3
# 17                         Bank               Baseball Field               3
# 18                    Drugstore          Dumpling Restaurant               3
# 19  Eastern European Restaurant          Dumpling Restaurant               3
# 20                   Steakhouse          Japanese Restaurant               3
# 21          Dumpling Restaurant            Electronics Store               3
# 22            Electronics Store                 Dessert Shop               3
# 23                   Donut Shop                    Drugstore               3
# 24            Electronics Store  Eastern European Restaurant               3
# 25          Sporting Goods Shop           Chinese Restaurant               3
# 27                   Donut Shop                    Drugstore               3
# 28             Doner Restaurant                   Donut Shop               3
# 29                   Donut Shop                    Drugstore               3
# 30               Discount Store                  Event Space               3
# 31             Doner Restaurant                   Donut Shop               3
# 32                      Dog Run             Doner Restaurant               3
# 33           Rock Climbing Spot               Breakfast Spot               3
# 34                 Gourmet Shop             Department Store               3
# 35                    Drugstore          Dumpling Restaurant               3
# 36                Shopping Mall               Breakfast Spot               3
# 37                  Yoga Studio                  Coffee Shop               3
# 38          Dumpling Restaurant            Electronics Store               3
# 39                   Restaurant                         Café               3
# 41                 Neighborhood    Latin American Restaurant               3
# 42                    Drugstore  Eastern European Restaurant               3
# 43  Eastern European Restaurant          Dumpling Restaurant               3
# 44           Salon / Barbershop                Metro Station               3
# 45          Fried Chicken Joint                      Brewery               3
# 47                  Pizza Place                   Restaurant               3
# 48             Doner Restaurant                   Donut Shop               3
# 49                       Market                  Pizza Place               3
# 50     Mediterranean Restaurant                  Men's Store               3
# 51           Mexican Restaurant               Farmers Market               3
# 52          Japanese Restaurant                        Plaza               3
# 53                       Bakery               Cosmetics Shop               3
# 54                   Steakhouse                       Bakery               3
# 55           Chinese Restaurant          Japanese Restaurant               3
# 56                          Bar             Asian Restaurant               3
# 57           Italian Restaurant                       Bakery               3
# 59           Seafood Restaurant                   Steakhouse               3
# 60                  Pizza Place                     Pharmacy               3
# 61                      Dog Run             Doner Restaurant               3
# 63            French Restaurant            Indian Restaurant               3
# 64                    Nightclub                 Noodle House               3
# 66                      Airport           Airport Food Court               3
# 67               Cosmetics Shop                     Creperie               3
# 68                   Steakhouse             Asian Restaurant               3
# 69                Women's Store        Vietnamese Restaurant               3
# 70             Doner Restaurant                   Donut Shop               3
# 71                   Donut Shop                    Drugstore               3
# 73                   Baby Store                  Coffee Shop               3
# 75                  Pizza Place                      Brewery               3
# 76       Furniture / Home Store                Grocery Store               3
# 77          Dumpling Restaurant  Eastern European Restaurant               3
# 78                    Drugstore                  Yoga Studio               3
# 79             Doner Restaurant                   Donut Shop               3
# 81                      Dog Run           Italian Restaurant               3
# 82                  Fish Market            Fish & Chips Shop               3
# 83                     Boutique           Seafood Restaurant               3
# 84                      Dog Run             Doner Restaurant               3
# 85                      Butcher                          Spa               3
# 86                    Pet Store                  Pizza Place               3
# 87                  Coffee Shop                   Comic Shop               3
# 88             Doner Restaurant                   Donut Shop               3
# 90            Convenience Store              Supplement Shop               3
# 91            Electronics Store          Filipino Restaurant               3
# 92             Department Store          Empanada Restaurant               3
# 94                  Yoga Studio          Filipino Restaurant               3
# 95                    Drugstore            Electronics Store               3
# 96                      Dog Run             Doner Restaurant               3
# 97             Doner Restaurant                   Donut Shop               3
# 98                   Beer Store          Japanese Restaurant               3
